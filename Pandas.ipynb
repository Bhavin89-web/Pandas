# %%
#pandas:

# %%
#dataframe
#slicing: iloc, loc
#merge and join: joining multiple tables
#set_index: 
#rename
#pivot

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
Emp=pd.DataFrame({'Eid':[11,12,13,14],
                 'Ename':['Krishna','Rama','Bheema','Balarama'],
                 'Age':[23,24,25,26],
                 'Did':['D0','D1','D2','D4']})
Emp
# Out:
#    Eid     Ename  Age Did
# 0   11   Krishna   23  D0
# 1   12      Rama   24  D1
# 2   13    Bheema   25  D2
# 3   14  Balarama   26  D4

# %%
Dept=pd.DataFrame({'Did':['D0','D1','D4','D5'],
                 'Dname':['Marketing','Production','IT','Testing'],
                 'Dloc':['Goa','Mathura','Delhi','Bangalore']})
Dept
# Out:
#   Did       Dname       Dloc
# 0  D0   Marketing        Goa
# 1  D1  Production    Mathura
# 2  D4          IT      Delhi
# 3  D5     Testing  Bangalore

# %%
Dept=pd.DataFrame({'Did':['D0','D1','D4','D5'],
                 'Dname':['Marketing','Production','IT','Testing'],
                 'Dloc':['Goa','Mathura','Delhi','Bangalore']})
Dept
# Out:
#   Did       Dname       Dloc
# 0  D0   Marketing        Goa
# 1  D1  Production    Mathura
# 2  D4          IT      Delhi
# 3  D5     Testing  Bangalore

# %%
#slicing
#iloc: integer based

# %%
Emp
# Out:
#    Eid     Ename  Age Did
# 0   11   Krishna   23  D0
# 1   12      Rama   24  D1
# 2   13    Bheema   25  D2
# 3   14  Balarama   26  D4

# %%
Emp.iloc[:,:]
# Out:
#    Eid     Ename  Age Did
# 0   11   Krishna   23  D0
# 1   12      Rama   24  D1
# 2   13    Bheema   25  D2
# 3   14  Balarama   26  D4

# %%
Emp.iloc[0:2,:]
# Out:
#    Eid    Ename  Age Did
# 0   11  Krishna   23  D0
# 1   12     Rama   24  D1

# %%
Emp.iloc[0:2,0:2]
# Out:
#    Eid    Ename
# 0   11  Krishna
# 1   12     Rama

# %%
Emp.iloc[0:,0:2]
# Out:
#    Eid     Ename
# 0   11   Krishna
# 1   12      Rama
# 2   13    Bheema
# 3   14  Balarama

# %%
Emp.iloc[[0,3]]
# Out:
#    Eid     Ename  Age Did
# 0   11   Krishna   23  D0
# 3   14  Balarama   26  D4

# %%
Emp.loc[:,:]
# Out:
#    Eid     Ename  Age Did
# 0   11   Krishna   23  D0
# 1   12      Rama   24  D1
# 2   13    Bheema   25  D2
# 3   14  Balarama   26  D4

# %%
Emp.loc[0:2,:]
# Out:
#    Eid    Ename  Age Did
# 0   11  Krishna   23  D0
# 1   12     Rama   24  D1
# 2   13   Bheema   25  D2

# %%
Emp.loc[0:2,'Eid':'Age']
# Out:
#    Eid    Ename  Age
# 0   11  Krishna   23
# 1   12     Rama   24
# 2   13   Bheema   25

# %%
Emp.loc[0:2,'Age':'Did']
# Out:
#    Age Did
# 0   23  D0
# 1   24  D1
# 2   25  D2

# %%
Emp.loc[[2,3]]
# Out:
#    Eid     Ename  Age Did
# 2   13    Bheema   25  D2
# 3   14  Balarama   26  D4

# %%
Emp.loc[0:2,['Eid','Did']]
# Out:
#    Eid Did
# 0   11  D0
# 1   12  D1
# 2   13  D2

# %%
Dept
# Out:
#   Did       Dname       Dloc
# 0  D0   Marketing        Goa
# 1  D1  Production    Mathura
# 2  D4          IT      Delhi
# 3  D5     Testing  Bangalore

# %%
Dept.loc[lambda x:Dept.Dname=='Marketing',["Dname",'Dloc']]
# Out:
#        Dname Dloc
# 0  Marketing  Goa

# %%
#Retrive only department information where location is Bangalore

# %%
Dept.loc[lambda x:Dept.Dloc=='Bangalore',["Dname",'Dloc']]
# Out:
#      Dname       Dloc
# 3  Testing  Bangalore

# %%
#joining multiple tables: merge, join

# %%
#merge: we have to mention on what basis we are joining multiple tables

# %%
Emp
# Out:
#    Eid     Ename  Age Did
# 0   11   Krishna   23  D0
# 1   12      Rama   24  D1
# 2   13    Bheema   25  D2
# 3   14  Balarama   26  D4

# %%
Dept
# Out:
#   Did       Dname       Dloc
# 0  D0   Marketing        Goa
# 1  D1  Production    Mathura
# 2  D4          IT      Delhi
# 3  D5     Testing  Bangalore

# %%
pd.merge(Emp,Dept,on='Did')
# Out:
#    Eid     Ename  Age Did       Dname     Dloc
# 0   11   Krishna   23  D0   Marketing      Goa
# 1   12      Rama   24  D1  Production  Mathura
# 2   14  Balarama   26  D4          IT    Delhi

# %%
pd.merge(Emp,Dept,on='Did',how='inner')
# Out:
#    Eid     Ename  Age Did       Dname     Dloc
# 0   11   Krishna   23  D0   Marketing      Goa
# 1   12      Rama   24  D1  Production  Mathura
# 2   14  Balarama   26  D4          IT    Delhi

# %%
pd.merge(Emp,Dept,on='Did',how='left')
# Out:
#    Eid     Ename  Age Did       Dname     Dloc
# 0   11   Krishna   23  D0   Marketing      Goa
# 1   12      Rama   24  D1  Production  Mathura
# 2   13    Bheema   25  D2         NaN      NaN
# 3   14  Balarama   26  D4          IT    Delhi

# %%
pd.merge(Emp,Dept,on='Did',how='right')
# Out:
#     Eid     Ename   Age Did       Dname       Dloc
# 0  11.0   Krishna  23.0  D0   Marketing        Goa
# 1  12.0      Rama  24.0  D1  Production    Mathura
# 2  14.0  Balarama  26.0  D4          IT      Delhi
# 3   NaN       NaN   NaN  D5     Testing  Bangalore

# %%
pd.merge(Emp,Dept,on='Did',how='outer')
# Out:
#     Eid     Ename   Age Did       Dname       Dloc
# 0  11.0   Krishna  23.0  D0   Marketing        Goa
# 1  12.0      Rama  24.0  D1  Production    Mathura
# 2  13.0    Bheema  25.0  D2         NaN        NaN
# 3  14.0  Balarama  26.0  D4          IT      Delhi
# 4   NaN       NaN   NaN  D5     Testing  Bangalore

# %%
df1=pd.DataFrame({'Mg_id':['Mg1','Mg2','Mg3','Mg4'],
                 'Mgr_name':['Arun','Surya','Shankar','Shamboo'],
                 'Did':['D0','D1','D7','D8']})

# %%
pd.merge(df1,(pd.merge(Emp,Dept,on='Did',how='inner')),how='inner')
# Out:
#   Mg_id Mgr_name Did  Eid    Ename  Age       Dname     Dloc
# 0   Mg1     Arun  D0   11  Krishna   23   Marketing      Goa
# 1   Mg2    Surya  D1   12     Rama   24  Production  Mathura

# %%
df1
# Out:
#   Mg_id Mgr_name Did
# 0   Mg1     Arun  D0
# 1   Mg2    Surya  D1
# 2   Mg3  Shankar  D7
# 3   Mg4  Shamboo  D8

# %%
pd.merge(df1,(pd.merge(Emp,Dept,on='Did',how='inner')),how='inner')
# Out:
#   Mg_id Mgr_name Did  Eid    Ename  Age       Dname     Dloc
# 0   Mg1     Arun  D0   11  Krishna   23   Marketing      Goa
# 1   Mg2    Surya  D1   12     Rama   24  Production  Mathura

# %%
#join: join based on the index values

# %%
Emp
# Out:
#    Eid     Ename  Age Did
# 0   11   Krishna   23  D0
# 1   12      Rama   24  D1
# 2   13    Bheema   25  D2
# 3   14  Balarama   26  D4

# %%
Dept
# Out:
#   Did       Dname       Dloc
# 0  D0   Marketing        Goa
# 1  D1  Production    Mathura
# 2  D4          IT      Delhi
# 3  D5     Testing  Bangalore

# %%
Emp.join(Dept)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 Emp.join(Dept)
#
# File ~\anaconda31\lib\site-packages\pandas\core\frame.py:9979, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9816 def join(
#    9817     self,
#    9818     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9824     validate: str | None = None,
#    9825 ) -> DataFrame:
#    9826     """
#    9827     Join columns of another DataFrame.
#    9828
#    (...)
#    9977     5  K1  A5   B1
#    9978     """
# -> 9979     return self._join_compat(
#    9980         other,
#    9981         on=on,
#    9982         how=how,
#    9983         lsuffix=lsuffix,
#    9984         rsuffix=rsuffix,
#    9985         sort=sort,
#    9986         validate=validate,
#    9987     )
#
# ...

# %%
#set_index: we can make any column index column

# %%
Emp
# Out:
#    Eid     Ename  Age Did
# 0   11   Krishna   23  D0
# 1   12      Rama   24  D1
# 2   13    Bheema   25  D2
# 3   14  Balarama   26  D4

# %%
Emp.set_index('Did',inplace=True)

# %%
Emp
# Out:
#      Eid     Ename  Age
# Did
# D0    11   Krishna   23
# D1    12      Rama   24
# D2    13    Bheema   25
# D4    14  Balarama   26

# %%
Dept.set_index('Did',inplace=True)

# %%
Dept
# Out:
#           Dname       Dloc
# Did
# D0    Marketing        Goa
# D1   Production    Mathura
# D4           IT      Delhi
# D5      Testing  Bangalore

# %%
Emp.join(Dept)
# Out:
#      Eid     Ename  Age       Dname     Dloc
# Did
# D0    11   Krishna   23   Marketing      Goa
# D1    12      Rama   24  Production  Mathura
# D2    13    Bheema   25         NaN      NaN
# D4    14  Balarama   26          IT    Delhi

# %%
Emp.join(Dept,how='inner')
# Out:
#      Eid     Ename  Age       Dname     Dloc
# Did
# D0    11   Krishna   23   Marketing      Goa
# D1    12      Rama   24  Production  Mathura
# D4    14  Balarama   26          IT    Delhi

# %%
Emp.join(Dept,how='outer')
# Out:
#       Eid     Ename   Age       Dname       Dloc
# Did
# D0   11.0   Krishna  23.0   Marketing        Goa
# D1   12.0      Rama  24.0  Production    Mathura
# D2   13.0    Bheema  25.0         NaN        NaN
# D4   14.0  Balarama  26.0          IT      Delhi
# D5    NaN       NaN   NaN     Testing  Bangalore

# %%
Emp.join(Dept,how='right')
# Out:
#       Eid     Ename   Age       Dname       Dloc
# Did
# D0   11.0   Krishna  23.0   Marketing        Goa
# D1   12.0      Rama  24.0  Production    Mathura
# D4   14.0  Balarama  26.0          IT      Delhi
# D5    NaN       NaN   NaN     Testing  Bangalore

# %%
df1
# Out:
#   Mg_id Mgr_name Did
# 0   Mg1     Arun  D0
# 1   Mg2    Surya  D1
# 2   Mg3  Shankar  D7
# 3   Mg4  Shamboo  D8

# %%
df1.set_index('Did',inplace=True)

# %%
df1
# Out:
#     Mg_id Mgr_name
# Did
# D0    Mg1     Arun
# D1    Mg2    Surya
# D7    Mg3  Shankar
# D8    Mg4  Shamboo

# %%
Emp.join(Dept,how='inner')
# Out:
#      Eid     Ename  Age       Dname     Dloc
# Did
# D0    11   Krishna   23   Marketing      Goa
# D1    12      Rama   24  Production  Mathura
# D4    14  Balarama   26          IT    Delhi

# %%
df1.join(Emp.join(Dept,how='inner'),how='inner')
# Out:
#     Mg_id Mgr_name  Eid    Ename  Age       Dname     Dloc
# Did
# D0    Mg1     Arun   11  Krishna   23   Marketing      Goa
# D1    Mg2    Surya   12     Rama   24  Production  Mathura
